# %% [markdown]
# # Cool down ADR1

# %% [markdown]
# ## Run 'Logger Acquire' if it's not running. Then run 'Logger Visualize' to plot temperatures

# %% [markdown]
# ## Close heat switch. Important!

# %%
import ADR1MagCycle
ADR1MagCycle.MagCycle.close_heat_switch()    # closes heat switch
# Out:
# INFO:root:Heat switch closed @02/02/21, 15:42:35.

# %%
import ADR1MagCycle
ADR1MagCycle.MagCycle.open_heat_switch()    # open heat switch
# Out:
# INFO:root:Heat switch opened @02/01/21,18:39:09.

# %% [markdown]
# ## Pump vaccum can down to low $10^{-4}$ Torr.

# %% [markdown]
# ## Turn on compressor & cooling water. Make sure the oil temperature in  85-105 F.

# %% [markdown]
# # While ADR1 is cold ...

# %% [markdown]
# ## Run Mag Cycle immediately

# %%
# %matplotlib qt5
import ADR1MagCycle

#Note: Heat Switch wont close until FAA is ~3K
#COM9 is the heat switch - Sometimes needs to be unplugged and plugged back in before first mag cycle. 

how_long_to_soak = 1 # in hour
timestep_magup = 3 # in sec, default = 3
timestep_magdown = 3 # in sec, default = 5

ADR1MagCycle.MagCycle.run_mag_cycle(soak_hour=how_long_to_soak
                                    , timestep_magup=timestep_magup
                                    , timestep_magdown=timestep_magdown)
# Out:
# INFO:root:Mag cycle started @15:49:07!
# INFO:root:All instrument connected
# INFO:root:Magup started @15:49:11!
# INFO:root:Voltage is ramping up...
# INFO:root:Heat switch closed @15:58:28.
# INFO:root:Waiting to reach the max current 9.2 A...
# INFO:root:Current reached the max current 9.2 A...
# INFO:root:Magup finished @16:28:29!!
# INFO:root:Heat switch opened @16:28:34.
# INFO:root:Heat switch closed @16:28:39.
# INFO:root:Soak started @16:28:39 and will last for 1 hr.
# INFO:root:Soak finished @17:28:51
# INFO:root:Magdown started @17:28:51!
# INFO:root:Heat switch opened @17:28:56.
# INFO:root:Voltage is ramping down to zero...
# INFO:root:Waiting to reach 0 A...
# INFO:root:Magdown finished @18:49:51!
# INFO:root:Mag cycle ended @18:49:51! Yeah!

# %%
import ADR1MagCycle
ADR1MagCycle.MagCycle.run_mag_down_only()
# Out:
# INFO:root:Magdown started @02/01/21, 18:39:10!
# INFO:root:All instrument connected
# INFO:root:Magdown started @18:39:13!
# INFO:root:Heat switch opened @18:39:18.
# INFO:root:Voltage is ramping down to zero...
# INFO:root:Waiting to reach 0 A...
# INFO:root:Magdown finished @20:18:32!
# INFO:root:Magdown ended @02/01/21, 20:18:32! Yeah!

# %% [markdown]
# ## Run a scheduled Mag Cycle

# %%
# %matplotlib qt5
import ADR1MagCycle
import datetime

# Schedule a mag cycle to start at specific date and time. 
# Take into account that the magup and magdown normally take ~2.5 hr in otal.
scheduled_datetime = datetime.datetime(2021, 2, 5, 7, 0) # (year, month, day, hour, minute)
how_long_to_soak = 1  # in hours

ADR1MagCycle.MagCycle.schedule_mag_cycle(scheduled_datetime, soak_hour=how_long_to_soak)
# Out:
# Scheduled date/time are correct? (y/n)y
# INFO:root:Mag cycle is scheduled to start @02/05/21. 07:00:00
# INFO:root:Waiting to start a mag cycle...
# INFO:root:Mag cycle started @07:00:41!
# INFO:root:All instrument connected
# INFO:root:Magup started @07:00:44!
# INFO:root:Voltage is ramping up...
# INFO:root:Heat switch closed @07:30:27.
# INFO:root:Waiting to reach the max current 9.2 A...
# INFO:root:Current reached the max current 9.2 A...
# INFO:root:Magup finished @07:39:53!!
# INFO:root:Heat switch opened @07:39:58.
# INFO:root:Heat switch closed @07:40:03.
# INFO:root:Soak started @07:40:03 and will last for 1 hr.
# INFO:root:Soak finished @08:40:15
# INFO:root:Magdown started @08:40:15!
# INFO:root:Heat switch opened @08:40:20.
# INFO:root:Voltage is ramping down to zero...
# INFO:root:Waiting to reach 0 A...
# INFO:root:Magdown finished @10:19:48!
# INFO:root:Mag cycle ended @10:19:48! Yeah!
# INFO:root:Scheduled mag cycle is complete @02/05/21, 10:19:48! Yeah!

# %% [markdown]
# # Warm up ADR1

# %% [markdown]
# ## (Optional) Close heat switch

# %%
import ADR1MagCycle
ADR1MagCycle.MagCycle.close_heat_switch()
# Out:
# INFO:root:Heat switch closed @11/24/20, 21:11:35.

# %% [markdown]
# ## Turn off compressor & cooling water.

# %% [markdown]
# ## Inject a puff of nitrogen gas into the fridge. The end!

# %% [markdown]
# If you want faster warm-up, vent the fridge up to 1 atm and set up a fan once all temperatures get higher than 77K.
